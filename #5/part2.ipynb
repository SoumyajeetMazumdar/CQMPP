# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

def ke_matrix(n):
    # Create Crank-Nicolson matrices (A^+ and A^-)
    T = np.zeros((n, n))
    for i in range(n):
        for j in range(n):
            if i == j:
                T[i,j] = -2
            if abs(i - j) == 1:
                T[i,j] = 1
                
    return T
    
def pe_matrix(x, x_barrier, V_barrier):
    V_grid = np.zeros_like(x)
    
    for i in range(0, len(x)):
        if x[i] >= x_barrier:
            V_grid[i] = V_barrier
        else:
            V_grid[i] = 0 

    # step potential graphically verified, correct
    # plt.plot(x, V_grid)   
    V = np.zeros((len(x), len(x)))
    for i in range(0, len(x)):
        V[i,i] = V_grid[i]
    
    return V
    
# since we assume dirichlet boundary conditions here, there is no need to implement the b matrix


# implementation of thomas algorithm to speed up the processing of tridiagonal matrices.
# functioning verified with different test cases before implementation here
def thomas(A,d):
    """ A is the tridiagnonal coefficient matrix and d is the RHS matrix"""
    
    # Extraction of the diagonal, sub and super diagonal elements into arrays for further computations
    # Extract diagonals
    b = np.diag(A)       # Main diagonal
    c = np.diag(A, k=1) # Super-diagonal
    a =   np.diag(A, k=-1)  # Sub-diagonal

    a = np.insert(a, 0, 0) # making these arrays equivalent in length to the diagonal array
    c = np.append(c, 0)
    
    
    N = len(d)
    cp = np.zeros(N,dtype='float64') # store tranformed c or c'
    dp = np.zeros(N,dtype='float64') # store transformed d or d'
    X = np.zeros(N,dtype='float64') # store unknown coefficients
    
    # Perform Forward Sweep
    # Equation 1 indexed as 0 in python
    cp[0] = c[0]/b[0]  
    dp[0] = d[0]/b[0]
    # Equation 2, ..., N (indexed 1 - N-1 in Python)
    for i in np.arange(1,(N),1):
        dnum = b[i] - a[i]*cp[i-1]
        cp[i] = c[i]/dnum
        dp[i] = (d[i]-a[i]*dp[i-1])/dnum
    
    # Perform Back Substitution
    X[(N-1)] = dp[N-1]  # Obtain last xn 

    for i in np.arange((N-2),-1,-1):  # use x[i+1] to obtain x[i]
        X[i] = (dp[i]) - (cp[i])*(X[i+1])
    
    return(X)

# %%
# defining spatial grid
dx = 0.01
x_min, x_max = -30, 30  
x = np.arange(x_min, x_max + dx, dx)

# constructing the KE and PE operator matrices, to create the Hamilton matrix for CN propagator
# KE is approximated using the 3-point stencil formula, the matrix of which is returned from the above
T = ke_matrix(len(x))
V = pe_matrix(x, x_barrier=20, V_barrier=0)

# constructing the hamilton operators in this case
H = -1/(2*dx**2) * T + V


# defining the time grid, which is need prior to the creation of the CN operators in this case.
dt = 0.01
t = np.arange(0, 2 + dt, dt)


# constructing the CN operators A+ and A-, using the 3 point
# simply adding one adds to each element of the matrices, violating tri-diagonal nature
A_minus = np.eye(len(x)) + 1j * dt/2 * H
A_plus = np.eye(len(x)) - 1j * dt/2 * H

# %%
# As given in the question, psi0 in created here
k0 = 4
x0 = -10
sigma0 = 2
psi_initial = np.exp(1j * k0 * x) * np.exp(-(x - x0)**2 / (2 * sigma0**2))
# plt.plot(x, psi_initial) 

# Compute the normalization factor
prob_density = np.abs(psi_initial)**2
norm_factor = np.sqrt(np.sum(prob_density) * dx)

# Normalize the wavefunction
psi_normalized = psi_initial / norm_factor

# %%
# Tridiagonal check function, important for operator matrices troubleshooting when initial run failed.
# successfully verified ###

# def is_tridiagonal(matrix):
#     n, m = matrix.shape
#     if n != m:
#         return False  # Not a square matrix

#     for i in range(n):
#         for j in range(n):
#             if abs(i - j) > 1 and matrix[i, j] != 0:
#                 return False
#     return True

# is_tridiagonal(A_minus), is_tridiagonal(A_plus)

# %%
# actual calculations start here
psi = np.zeros((len(t), len(x))) 
psi[0] = psi_normalized.copy()


for i in range(1, len(t)):
    psi_n = psi[i-1] # from the last step
    psi_intermediate = np.dot(A_plus, psi_n)
    psi_n_plus_1 = thomas(A_minus, psi_intermediate)
    
    
    psi[i] = psi_n_plus_1


pdffile = "tdse.pdf"

with PdfPages(pdffile) as pdf:
    for i in range(0, len(t)):
        # creating plot
        # plt.plot(x,psi[0], "r", label=f"at time step = {round(t[0],5)}")
        plt.plot(x,psi[i], "b",label=f"at time step = {round(t[i],5)}")
        plt.legend()
        plt.xlabel("x")
        plt.ylabel("psi(x,t)")
        plt.title(f"Wavefunction: dx={dx}, iter = {len(t)-1}")
        
        # exporting to the pdf.
        pdf.savefig()
        plt.close()
# Out:
# /tmp/ipykernel_8219/3242812072.py:3: ComplexWarning: Casting complex values to real discards the imaginary part
#   psi[0] = psi_normalized.copy()
# /tmp/ipykernel_8219/3948713447.py:59: ComplexWarning: Casting complex values to real discards the imaginary part
#   cp[0] = c[0]/b[0]
# /tmp/ipykernel_8219/3948713447.py:60: ComplexWarning: Casting complex values to real discards the imaginary part
#   dp[0] = d[0]/b[0]
# /tmp/ipykernel_8219/3948713447.py:64: ComplexWarning: Casting complex values to real discards the imaginary part
#   cp[i] = c[i]/dnum
# /tmp/ipykernel_8219/3948713447.py:65: ComplexWarning: Casting complex values to real discards the imaginary part
#   dp[i] = (d[i]-a[i]*dp[i-1])/dnum
